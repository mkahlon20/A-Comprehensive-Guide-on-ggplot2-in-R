# %%
5 + 7
# Out:
# Failed to start the Kernel.
#
# File C:\Users\mohit\Documents/.Renviron contains invalid line(s)
#
#       '''r
#
#       '''r
#
#    They were ignored
#
#
#
# Error in loadNamespace(x) : there is no package called 'IRkernel'
#
# Calls: loadNamespace -> withRestarts -> withOneRestart -> doWithOneRestart
#
# Execution halted.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
abs(-17)
# Out:
# Failed to start the Kernel.
#
# File C:\Users\mohit\Documents/.Renviron contains invalid line(s)
#
#       '''r
#
#       '''r
#
#    They were ignored
#
#
#
# Error in loadNamespace(x) : there is no package called 'IRkernel'
#
# Calls: loadNamespace -> withRestarts -> withOneRestart -> doWithOneRestart
#
# Execution halted.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
x <- -12

# %%
x + 7
# Out:
# [1] -5

# %%
abs(x) #absoute value
# Out:
# [1] 12

# %%
y <- c(-12, 6, 0, -1) # vectors

# %%
y
# Out:
# [1] -12   6   0  -1

# %%
2 * y
# Out:
# [1] -24  12   0  -2

# %%
abs(y)
# Out:
# [1] 12  6  0  1
