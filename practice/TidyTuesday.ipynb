# %%
install.packages("tidytuesdayR")
# Out:
# Installing package into 'C:/Users/mohit/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
# package 'tidytuesdayR' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\mohit\AppData\Local\Temp\RtmpAxhgId\downloaded_packages

# %%
library(tidyverse)
library(tidytuesdayR)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# tt <- tt_load("YYYY-MM-DD")
# names(tt)
# glimpse(tt[[1]])

# %%
tt <- tt_load("2023-01-10")
# Out:
# ---- Compiling #TidyTuesday Information for 2023-01-10 ----
# --- There are 2 files available ---
#
#
# ── Downloading files ───────────────────────────────────────────────────────────
#
#   1 of 2: "PFW_2021_public.csv"
#   2 of 2: "PFW_count_site_data_public_2021.csv"

# %%
names(tt)
# Out:
# [1] "PFW_2021_public"                 "PFW_count_site_data_public_2021"

# %%
glimpse(tt[[1]])
# Out:
# Rows: 100,000
# Columns: 22
# $ loc_id             <chr> "L981010", "L3161698", "L13210778", "L13258348", "L…
# $ latitude           <dbl> 52.12976, 43.83221, 39.72147, 42.21787, 32.74992, 4…
# $ longitude          <dbl> -122.13547, -123.09240, -75.93366, -83.67230, -79.9…
# $ subnational1_code  <chr> "CA-BC", "US-OR", "US-MD", "US-MI", "US-SC", "CA-QC…
# $ entry_technique    <chr> "POSTCODE LAT/LONG LOOKUP", "/GOOGLE_MAP/ZOOM:18", …
# $ sub_id             <chr> "S83206450", "S78031190", "S81318993", "S79251313",…
# $ obs_id             <chr> "OBS1092604618", "OBS1036509564", "OBS1073386105", …
# $ Month              <dbl> 3, 12, 2, 1, 1, 3, 1, 4, 11, 1, 1, 4, 3, 11, 1, 2, …
# $ Day                <dbl> 4, 19, 13, 13, 11, 13, 23, 23, 28, 2, 30, 22, 25, 1…
# $ Year               <dbl> 2021, 2020, 2021, 2021, 2021, 2021, 2021, 2021, 202…
# $ PROJ_PERIOD_ID     <chr> "PFW_2021", "PFW_2021", "PFW_2021", "PFW_2021", "PF…
# ...

# %%
pfw <- tt$PFW_2021_public

# %%
pfw %>%
  ggplot(aes(x = Day, y = Year, color = )) + geom_point(color = "blue", size = 3)
# Out:
# plot without title
